# %%
# Runs glycan_contacts.py on 3AVE and 1GYA, merges results, and produces exploratory visualizations.

# %%
# Install and download
pip install biopython pandas numpy matplotlib seaborn -q
import urllib.request, os

# %% [markdown]
# #
